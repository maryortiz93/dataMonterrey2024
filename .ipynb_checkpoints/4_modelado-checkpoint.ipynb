# %%
# %matplotlib inline
import pandas as pd

# %%
compras_df=pd.read_csv('data/clean_compras_2024.csv')

# %%
# Creamos una copia del dataframe
data=compras_df.copy()

# %% [markdown]
# ### Llenar los valores faltantes del dataframe

# %%
# Completamos los datos faltantes y categorizamos las variables
for i, column in enumerate(list([str(d) for d in data.dtypes])):
    if column == "object":
        data[data.columns[i]]=data[data.columns[i]].fillna(data[data.columns[i]].mode())
        data[data.columns[i]]=data[data.columns[i]].astype("category").cat.codes
    else:
        data[data.columns[i]]=data[data.columns[i]].fillna(data[data.columns[i]].median())

# %%
data.head(4)
# Out:
#       C B  BENEFICIARIO   RFC  FACTURAS  CONTRATO  CONCEPTO  TIPO  \
# 0  126753           876   904      6710        44       537     1
# 1  126753           876   904      6488        44      1654     1
# 2  206273          1657  1560     11985        44      7672     1
# 3  206273          1657  1560      1077        44      7680     1
#
#      FDO - #OP  FECHA     IMPORTE  SHEET
# 0  351000898.0      0  2429742.44      1
# 1  351000899.0      0   906239.26      1
# 2    1029199.0      0     4889.00      1
# 3  353000038.0      0  1674610.00      1

# %% [markdown]
# ### **MODELO SUPERVISADO**

# %% [markdown]
# #### **RANDOM FOREST**

# %%
# Importamos las bibliotecas
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split

# %%
# Definimos las variables
y=data.pop('IMPORTE')
y
# Out:
# 0        2429742.44
# 1         906239.26
# 2           4889.00
# 3        1674610.00
# 4        2356642.00
#             ...
# 13737       1871.49
# 13738       2481.47
# 13739       2481.47
# 13740        825.68
# 13741       2064.20
# Name: IMPORTE, Length: 13742, dtype: float64

# %%
X=data.copy()
X
# Out:
#           C B  BENEFICIARIO   RFC  FACTURAS  CONTRATO  CONCEPTO  TIPO  \
# 0      126753           876   904      6710        44       537     1
# 1      126753           876   904      6488        44      1654     1
# 2      206273          1657  1560     11985        44      7672     1
# 3      206273          1657  1560      1077        44      7680     1
# 4      206273          1657  1560     11984        44      3288     1
# ...       ...           ...   ...       ...       ...       ...   ...
# 13737  203016           807   821      2200        44      5704     0
# 13738  203016           645   662      5205        44      5720     0
# 13739  203016          1069  1056      5124        44      5699     0
# 13740  203016            29   444       169        46      5729     0
# 13741  203016          1133  1142      1943        44      5684     0
#
#          FDO - #OP  FECHA  SHEET
# 0      351000898.0      0      1
# 1      351000899.0      0      1
# 2        1029199.0      0      1
# 3      353000038.0      0      1
# 4      354000119.0      0      1
# ...            ...    ...    ...
# 13737  373000509.0    147      3
# 13738  373000510.0    147      3
# 13739  373000511.0    147      3
# 13740  373000512.0    147      3
# 13741  373000513.0    147      3
#
# [13742 rows x 10 columns]

# %% [markdown]
# #### **Dividimos los datos en 2 grupos**

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
# Creamos un clasificador
clf = RandomForestRegressor(n_estimators=1000, max_depth = 4)

# %%
# Entrenamos el modelo
clf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=4, n_estimators=1000)

# %%
# Evaluamos el rendimiento del modelo

# %%
# Importamos la libreria
from sklearn.metrics import r2_score

# %%
# Realizamos las predicciones
r2_score(y_test, clf.predict(X_test))
# Out:
# 0.22704951390244976

# %%
# Como resultado obtuvimos que el modelo explica:
# el 22.7% de la variabilidad de la variable dependiente.
# lo cual no representa un ajuste muy bueno.

# %% [markdown]
# ### **MODELO NO SUPERVISADO O DE CLUSTERING**

# %%
# Importamos las librerias
import warnings
warnings.filterwarnings("ignore",category=UserWarning, module="sklearn")
import numpy as np
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# %%
compras_df_c = compras_df.copy()

# %%
# Agrupamos los datos combinados con los valores unicos de la columna contrato y factura por beneficiario
# Incluimos la variable SHEET
compras_df_c_grupo = compras_df_c.groupby('BENEFICIARIO').agg({'CONTRATO': lambda x: x.nunique(), 'IMPORTE': 'sum',
                                                              'FACTURAS': lambda x: x.nunique(),'SHEET': lambda x: x.nunique()})

# %%
compras_df_cluster = compras_df_c_grupo.reset_index()
compras_df_cluster
# Visualizams el beneficiario con su numero de contrato,
# la suma del importe, el numero de facturas y la categoría
# Out:
#                                         BENEFICIARIO  CONTRATO    IMPORTE  \
# 0                                  A.R. CANALES S.C.         1   20398.64
# 1                            ABAD MORENO MILCA SARAI         1    8925.91
# 2     ABASTECEDORA DE EMPACADORAS Y RASTROS SA DE CV         1   20783.52
# 3                                   ABUNDIS  ALBERTO         1  316296.22
# 4         ABURTO HERRERA ANDREA MARIA DE LOS ANGELES         1   30518.37
# ...                                              ...       ...        ...
# 1813                              ZAVALA ROMERO OMAR         1   10458.85
# 1814                   ZEPEDA GONZALEZ DANIEL MARINO         1   17690.88
# 1815                            ZUÑIGA FRIAS MARIBEL         1   21536.42
# 1816                          ZUÑIGA GUERRERO MARTHA         1   68319.74
# 1817                     ZUÑIGA RAMIREZ ERIKA JAZMIN         1  203636.56
#
#       FACTURAS  SHEET
# 0            1      1
# 1            1      1
# 2            1      1
# 3            8      2
# 4            2      1
# ...        ...    ...
# 1813         1      1
# 1814         2      1
# 1815         1      1
# 1816         1      1
# 1817         2      1
#
# [1818 rows x 5 columns]

# %%
# Eliminamos la columna beneficiario
compras_df_c_grupo_f = compras_df_c_grupo.reset_index().drop(['BENEFICIARIO'], axis=1)

# %%
# Normalizamos los datos
normalizado_compras_df = (compras_df_c_grupo_f - compras_df_c_grupo_f.min())/(compras_df_c_grupo_f.max()-compras_df_c_grupo_f.min())
normalizado_compras_df
# Out:
#       CONTRATO   IMPORTE  FACTURAS  SHEET
# 0          0.0  0.000016  0.000000    0.0
# 1          0.0  0.000007  0.000000    0.0
# 2          0.0  0.000016  0.000000    0.0
# 3          0.0  0.000250  0.003838    0.5
# 4          0.0  0.000024  0.000548    0.0
# ...        ...       ...       ...    ...
# 1813       0.0  0.000008  0.000000    0.0
# 1814       0.0  0.000014  0.000548    0.0
# 1815       0.0  0.000017  0.000000    0.0
# 1816       0.0  0.000054  0.000000    0.0
# 1817       0.0  0.000161  0.000548    0.0
#
# [1818 rows x 4 columns]

# %% [markdown]
# #### **Implementamos el metodo "Codo de Jambu"**

# %%
# Inicializamos una lista
wcss=[]

# %%
# Ejecutamos Kmeans por los diferentes numeros de cluster
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, max_iter=300)
    kmeans.fit(normalizado_compras_df)
    wcss.append(kmeans.inertia_)

# %%
# Graficamos el codo de jambu
plt.plot(range(1,11), wcss)
plt.title('codo de jambu')
plt.xlabel('Numero de cluster')
plt.ylabel('WCSS') #Indica la cantidad de similitud de los individuos
plt.show()

# %%
# Determinamos el numero optimo de cluster, en este caso esta en el rango de 2 a 4

# %%
# Creamos una nueva instancia con 3 cluster
clustering = KMeans(n_clusters = 3, max_iter= 300)

# %%
# Entrenamos el modelo
clustering.fit(normalizado_compras_df)
# Out:
# KMeans(n_clusters=3)

# %%
# Asignamos las etiquetas a cada observacion
compras_df_cluster['KMeans_Cluster'] = clustering.labels_

# %%
compras_df_cluster['KMeans_Cluster'].value_counts()
# Out:
# KMeans_Cluster
# 0    1639
# 1     168
# 2      11
# Name: count, dtype: int64

# %% [markdown]
# #### **Implementamos PCA**

# %%
# Importamos la libreria
from sklearn.decomposition import PCA

# %%
# Creamos una instancia de PCA y definimos 2 componentes principales o 2 dimensiones
pca=PCA(n_components=2)

# %%
# Ajustamos y Transformamos los datos a las 2 dimensiones
pca_compras = pca.fit_transform(normalizado_compras_df)

# %%
# Convertimos a un dataframe de pandas
pca_compras_df = pd.DataFrame(data = pca_compras, columns = ['componente_1', 'componente_2'])

# %%
# Concatenamos con los nombres de los beneficiarios
pca_nombres_beneficiarios = pd.concat([pca_compras_df, compras_df_cluster['KMeans_Cluster']], axis=1)
pca_nombres_beneficiarios
# Out:
#       componente_1  componente_2  KMeans_Cluster
# 0        -0.052809     -0.002372               0
# 1        -0.052809     -0.002372               0
# 2        -0.052809     -0.002372               0
# 3         0.444537     -0.049982               1
# 4        -0.052793     -0.002129               0
# ...            ...           ...             ...
# 1813     -0.052809     -0.002372               0
# 1814     -0.052794     -0.002129               0
# 1815     -0.052809     -0.002372               0
# 1816     -0.052808     -0.002372               0
# 1817     -0.052789     -0.002130               0
#
# [1818 rows x 3 columns]

# %%
# Graficamos los Clusters
plt.figure(figsize=(10,8))

# %%
scatter = plt.scatter(pca_nombres_beneficiarios['componente_1'],
                     pca_nombres_beneficiarios['componente_2'],
                     c=pca_nombres_beneficiarios['KMeans_Cluster'],
                     cmap='viridis',
                     s=100,
                     alpha=0.7)
plt.title('Clusters formados mediante KMeans y PCA')
plt.xlabel('Componente 1')
plt.ylabel('Componente 2')
legend1 = plt.legend(*scatter.legend_elements(), title='Clusters')
plt.gca().add_artist(legend1)
plt.grid()
plt.show()
